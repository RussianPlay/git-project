# %% [markdown]
# <a href="https://colab.research.google.com/github/RussianPlay/git-project/blob/main/git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Локальный репозиторий**

# %% [markdown]
# 1. ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. ![image.png](data:image/png;base64,...)

# %% [markdown]
# 6.![image.png](data:image/png;base64,...)

# %% [markdown]
# 7.![image.png](data:image/png;base64,...)

# %% [markdown]
# 8. ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9. ![image.png](data:image/png;base64,...)

# %% [markdown]
# 10.![image.png](data:image/png;base64,...)

# %% [markdown]
# 11.![image.png](data:image/png;base64,...)

# %% [markdown]
# 12.![image.png](data:image/png;base64,...)

# %% [markdown]
# 13.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 14.![image.png](data:image/png;base64,...)

# %% [markdown]
# 15.![image.png](data:image/png;base64,...)

# %% [markdown]
# 16.![image.png](data:image/png;base64,...)

# %% [markdown]
# 17.![image.png](data:image/png;base64,...)

# %% [markdown]
# 18.![image.png](data:image/png;base64,...)

# %% [markdown]
# 19.![image.png](data:image/png;base64,...)

# %% [markdown]
# 20.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 21.
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 22.![image.png](data:image/png;base64,...)

# %% [markdown]
# 23.![image.png](data:image/png;base64,...)

# %% [markdown]
# 24.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 25.![image.png](data:image/png;base64,...)

# %% [markdown]
# 26.![image.png](data:image/png;base64,...)

# %% [markdown]
# 27.![image.png](data:image/png;base64,...)

# %% [markdown]
# 28.![image.png](data:image/png;base64,...)

# %% [markdown]
# 29.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 30.![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Удаленный репозиторий**

# %% [markdown]
# 1.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2.![image.png](data:image/png;base64,...)

# %% [markdown]
# 3.![image.png](data:image/png;base64,...)

# %% [markdown]
# 4.![image.png](data:image/png;base64,...)

# %% [markdown]
# 5.![image.png](data:image/png;base64,...)

# %% [markdown]
# 6.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 7.![image.png](data:image/png;base64,...)

# %% [markdown]
# 8.![image.png](data:image/png;base64,...)

# %% [markdown]
# 9.![image.png](data:image/png;base64,...)

# %% [markdown]
# 10.![image.png](data:image/png;base64,...)

# %% [markdown]
# 11.![image.png](data:image/png;base64,...)

# %% [markdown]
# 12.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 13.![image.png](data:image/png;base64,...)

# %% [markdown]
# 14.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 15.![image.png](data:image/png;base64,...)

# %% [markdown]
# 16.![image.png](data:image/png;base64,...)

# %% [markdown]
# 17.![image.png](data:image/png;base64,...)

# %% [markdown]
# 18.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 19.![image.png](data:image/png;base64,...)

# %% [markdown]
# 20.![image.png](data:image/png;base64,...)

# %% [markdown]
# 21.![image.png](data:image/png;base64,...)

# %% [markdown]
# 22.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 23.![image.png](data:image/png;base64,...)

# %% [markdown]
# 24.![image.png](data:image/png;base64,...)

# %% [markdown]
# 25.![image.png](data:image/png;base64,...)

# %% [markdown]
# 26.![image.png](data:image/png;base64,...)

# %% [markdown]
# 27.![image.png](data:image/png;base64,...)

# %% [markdown]
# 28.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 29.![image.png](data:image/png;base64,...)

# %% [markdown]
# 30.![image.png](data:image/png;base64,...)

# %% [markdown]
# 31.![image.png](data:image/png;base64,...)

# %% [markdown]
# 32.![image.png](data:image/png;base64,...)

# %% [markdown]
# 33.![image.png](data:image/png;base64,...)

# %% [markdown]
# 34.![image.png](data:image/png;base64,...)

# %% [markdown]
# 35.![image.png](data:image/png;base64,...)

# %% [markdown]
# 36.![image.png](data:image/png;base64,...)

# %% [markdown]
# 37.![image.png](data:image/png;base64,...)

# %% [markdown]
# 38.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 39.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 40.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 41.![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 42.![image.png](data:image/png;base64,...)

# %% [markdown]
# 43.![image.png](data:image/png;base64,...)

# %% [markdown]
# 44.![image.png](data:image/png;base64,...)

# %% [markdown]
# 45.![image.png](data:image/png;base64,...)

# %% [markdown]
# 46.![image.png](data:image/png;base64,...)

# %% [markdown]
# 47.![image.png](data:image/png;base64,...)

# %% [markdown]
# 48.![image.png](data:image/png;base64,...)

# %% [markdown]
# 49.![image.png](data:image/png;base64,...)

# %% [markdown]
# 50.![image.png](data:image/png;base64,...)
